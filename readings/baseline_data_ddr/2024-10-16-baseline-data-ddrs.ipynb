# %% [markdown]
# ## Set up environment

# %%
from dotenv import load_dotenv

_ = load_dotenv(override=True)

# %%
from common.context import TagPredictionContext

EXPERIMENT_ID = "2024-10-16-baseline-data-ddrs"
RUN_ID = "on-eval-dataset-v5"


CONTEXT = TagPredictionContext(
    description="Evaluate performance of the existing solution to set a baseline",
    experiment_id=EXPERIMENT_ID,
    run_id=RUN_ID,
    tags_in_scope=sorted(
        [
            "wait",
            "surfeqfailure",
            "tighthole",
            "lostcirculation",
            "packoff",
            "harddrilling",
            "stuckpipe",
            "wellcontrol",
            "wellborestability",
            "lowrop",
            "dircontrol",
            "highrop",
            "wellborebreathing",
            "boulders",
            "shallowgas",
            "dheqfailure",
            "holecleaning",
            "shallowwater",
        ]
    ),
    with_notags=True,
)

# %% [markdown]
# ## Fetch datasets
#
# The file "reviewed_distributed_ddr_v3.csv" was added with further corrections that were made with input from Informatiq.

# %%
import pandas as pd
import re
from common.datasets import load_input_dataset

dataset_name = "reviewed_distributed_ddr_v5.csv"

# Check if version number in dataset_name is 5 or greater
version_match = re.search(r'v(\d+)', dataset_name)
if version_match and int(version_match.group(1)) >= 5:
    reviewed_tags_column = "reviewedTags"
else:
    reviewed_tags_column = "Reviewed tags"

# Use the dynamically determined reviewed_tags_column
dataset_df = load_input_dataset(
    dataset_name, columns_to_convert_to_sets=["tags", reviewed_tags_column]
)

CONTEXT.used_datasets = [dataset_name]

# %% [markdown]
# ## Apply the model

# %%
# nothing to do, DDR tagging using regex rules is already applied to the dataset in this experiment
from common.assessment import expand_tags

assessed_df = dataset_df.filter(
    items=["id", "Text", "tags", reviewed_tags_column, "Comments"]
)
assessed_df = expand_tags(
    assessed_df,
    tags_in_scope=CONTEXT.tags_in_scope,
    ground_truth_tags_column=reviewed_tags_column,
    predicted_tags_column="tags",
)
assessed_df
# Out:
#                                                     id  expected__boulders  \
# 0    a1f86f80-135e-458b-aafc-3af30d2476f2_main_1e78...               False
# 1    a1f86f80-135e-458b-aafc-3af30d2476f2_main_0c00...               False
# 2    a1f86f80-135e-458b-aafc-3af30d2476f2_main_0f2c...               False
# 3    a1f86f80-135e-458b-aafc-3af30d2476f2_main_ff18...               False
# 4    a1f86f80-135e-458b-aafc-3af30d2476f2_main_821d...               False
# ..                                                 ...                 ...
# 295  a1f86f80-135e-458b-aafc-3af30d2476f2_main_aa5e...               False
# 296  a1f86f80-135e-458b-aafc-3af30d2476f2_main_5d39...               False
# 297  a1f86f80-135e-458b-aafc-3af30d2476f2_main_c0a8...               False
# 298  a1f86f80-135e-458b-aafc-3af30d2476f2_main_03d2...               False
# 299  a1f86f80-135e-458b-aafc-3af30d2476f2_main_f859...               False
#
#      actual__boulders  expected__dheqfailure  actual__dheqfailure  \
# 0               False                  False                False
# 1               False                  False                False
# 2               False                  False                False
# 3               False                  False                False
# 4               False                  False                False
# ..                ...                    ...                  ...
# 295             False                  False                False
# 296             False                  False                False
# 297             False                  False                False
# 298             False                  False                False
# 299             False                  False                False
#
#      expected__dircontrol  actual__dircontrol  expected__harddrilling  \
# 0                   False               False                   False
# 1                   False               False                   False
# 2                   False               False                   False
# 3                   False               False                   False
# 4                   False               False                   False
# ..                    ...                 ...                     ...
# 295                 False               False                   False
# 296                 False               False                   False
# 297                 False               False                   False
# 298                 False               False                   False
# 299                 False               False                   False
#
#      actual__harddrilling  expected__highrop  ...  expected__tighthole  \
# 0                   False              False  ...                False
# 1                   False              False  ...                False
# 2                   False              False  ...                False
# 3                   False              False  ...                False
# 4                   False              False  ...                False
# ..                    ...                ...  ...                  ...
# 295                 False              False  ...                False
# 296                 False              False  ...                False
# 297                 False              False  ...                False
# 298                 False              False  ...                False
# 299                 False              False  ...                False
#
#      actual__tighthole  expected__wait  actual__wait  \
# 0                False           False         False
# 1                False           False         False
# 2                False           False         False
# 3                False           False         False
# 4                False           False         False
# ..                 ...             ...           ...
# 295              False           False         False
# 296              False           False         False
# 297              False            True          True
# 298              False           False         False
# 299              False            True          True
#
#      expected__wellborebreathing  actual__wellborebreathing  \
# 0                          False                      False
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
# ..                           ...                        ...
# 295                        False                      False
# 296                        False                      False
# 297                        False                      False
# 298                        False                      False
# 299                        False                      False
#
#      expected__wellborestability  actual__wellborestability  \
# 0                          False                      False
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
# ..                           ...                        ...
# 295                        False                      False
# 296                        False                      False
# 297                        False                      False
# 298                        False                      False
# 299                        False                      False
#
#      expected__wellcontrol  actual__wellcontrol
# 0                    False                False
# 1                    False                False
# 2                    False                False
# 3                    False                False
# 4                    False                False
# ..                     ...                  ...
# 295                  False                False
# 296                  False                False
# 297                  False                False
# 298                  False                False
# 299                  False                False
#
# [300 rows x 37 columns]

# %%
from common.datasets import save_assessed_dataset


save_assessed_dataset(
    assessed_df,
    context=CONTEXT,
    experiment_id=EXPERIMENT_ID,
    run_id=RUN_ID,
)
# Out:
# 2_assessed_datasets\2024-10-16-baseline-data-ddrs-on-eval-dataset-v5

# %% [markdown]
# ## Evaluate predicted tags

# %%
from common.evaluation import TagMatchingEvaluator


evaluator = TagMatchingEvaluator(
    assessed_df=assessed_df,
    tags_in_scope=CONTEXT.tags_in_scope,
    with_notags=CONTEXT.with_notags,
)

# %%
evaluator.eval_individual_ddrs()
# Out:
#                                                     id  expected__boulders  \
# 0    a1f86f80-135e-458b-aafc-3af30d2476f2_main_1e78...               False
# 1    a1f86f80-135e-458b-aafc-3af30d2476f2_main_0c00...               False
# 2    a1f86f80-135e-458b-aafc-3af30d2476f2_main_0f2c...               False
# 3    a1f86f80-135e-458b-aafc-3af30d2476f2_main_ff18...               False
# 4    a1f86f80-135e-458b-aafc-3af30d2476f2_main_821d...               False
# ..                                                 ...                 ...
# 295  a1f86f80-135e-458b-aafc-3af30d2476f2_main_aa5e...               False
# 296  a1f86f80-135e-458b-aafc-3af30d2476f2_main_5d39...               False
# 297  a1f86f80-135e-458b-aafc-3af30d2476f2_main_c0a8...               False
# 298  a1f86f80-135e-458b-aafc-3af30d2476f2_main_03d2...               False
# 299  a1f86f80-135e-458b-aafc-3af30d2476f2_main_f859...               False
#
#      actual__boulders  expected__dheqfailure  actual__dheqfailure  \
# 0               False                  False                False
# 1               False                  False                False
# 2               False                  False                False
# 3               False                  False                False
# 4               False                  False                False
# ..                ...                    ...                  ...
# 295             False                  False                False
# 296             False                  False                False
# 297             False                  False                False
# 298             False                  False                False
# 299             False                  False                False
#
#      expected__dircontrol  actual__dircontrol  expected__harddrilling  \
# 0                   False               False                   False
# 1                   False               False                   False
# 2                   False               False                   False
# 3                   False               False                   False
# 4                   False               False                   False
# ..                    ...                 ...                     ...
# 295                 False               False                   False
# 296                 False               False                   False
# 297                 False               False                   False
# 298                 False               False                   False
# 299                 False               False                   False
#
#      actual__harddrilling  expected__highrop  ...  \
# 0                   False              False  ...
# 1                   False              False  ...
# 2                   False              False  ...
# 3                   False              False  ...
# 4                   False              False  ...
# ..                    ...                ...  ...
# 295                 False              False  ...
# 296                 False              False  ...
# 297                 False              False  ...
# 298                 False              False  ...
# 299                 False              False  ...
#
#      expected__wellborestability  actual__wellborestability  \
# 0                          False                      False
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
# ..                           ...                        ...
# 295                        False                      False
# 296                        False                      False
# 297                        False                      False
# 298                        False                      False
# 299                        False                      False
#
#      expected__wellcontrol  actual__wellcontrol  expected__notags  \
# 0                    False                False              True
# 1                    False                False              True
# 2                    False                False              True
# 3                    False                False             False
# 4                    False                False              True
# ..                     ...                  ...               ...
# 295                  False                False              True
# 296                  False                False             False
# 297                  False                False             False
# 298                  False                False              True
# 299                  False                False             False
#
#      actual__notags  precision  recall   f1  true_positives
# 0              True        1.0     1.0  1.0               1
# 1              True        1.0     1.0  1.0               1
# 2              True        1.0     1.0  1.0               1
# 3             False        1.0     1.0  1.0               1
# 4              True        1.0     1.0  1.0               1
# ..              ...        ...     ...  ...             ...
# 295            True        1.0     1.0  1.0               1
# 296           False        1.0     1.0  1.0               1
# 297           False        1.0     1.0  1.0               1
# 298            True        1.0     1.0  1.0               1
# 299           False        1.0     1.0  1.0               1
#
# [300 rows x 43 columns]

# %%
evaluator.eval_per_tag()
# Out:
#                   tag  precision    recall        f1  true_positives  \
# 0            boulders   0.000000  1.000000  0.000000               0
# 1         dheqfailure   0.000000  0.000000  0.000000               0
# 2          dircontrol   0.000000  1.000000  0.000000               0
# 3        harddrilling   0.500000  1.000000  0.666667               2
# 4             highrop   0.000000  1.000000  0.000000               0
# 5        holecleaning   1.000000  0.000000  0.000000               0
# 6     lostcirculation   0.777778  0.933333  0.848485              14
# 7              lowrop   0.727273  0.800000  0.761905               8
# 8             packoff   0.800000  1.000000  0.888889               4
# 9          shallowgas   1.000000  1.000000  1.000000               0
# 10       shallowwater   1.000000  1.000000  1.000000               0
# 11          stuckpipe   0.750000  0.750000  0.750000               3
# 12      surfeqfailure   0.600000  0.642857  0.620690              18
# 13          tighthole   0.384615  0.769231  0.512821              10
# 14               wait   1.000000  1.000000  1.000000              47
# 15  wellborebreathing   1.000000  1.000000  1.000000               3
# 16  wellborestability   1.000000  1.000000  1.000000               3
# 17        wellcontrol   1.000000  0.857143  0.923077               6
#
#     positives_in_ground_truth  negatives_in_ground_truth
# 0                           0                        300
# 1                           4                        296
# 2                           0                        300
# 3                           2                        298
# 4                           0                        300
# 5                           2                        298
# 6                          15                        285
# 7                          10                        290
# 8                           4                        296
# 9                           0                        300
# 10                          0                        300
# 11                          4                        296
# 12                         28                        272
# 13                         13                        287
# 14                         47                        253
# 15                          3                        297
# 16                          3                        297
# 17                          7                        293

# %%
evaluator.average_metrics()
# Out:
#               Type  precision    recall        f1
# 0  Average per DDR   0.824444  0.818333  0.818667
# 1  Average per Tag   0.641093  0.819587  0.609585

# %% [markdown]
# ## Save evaluation report

# %%
from common.datasets import save_evaluation_report

save_evaluation_report(
    experiment_id=EXPERIMENT_ID,
    run_id=RUN_ID,
    dataset_df=dataset_df,
    assessed_df=assessed_df,
    evaluator=evaluator,
    context=CONTEXT,
)
