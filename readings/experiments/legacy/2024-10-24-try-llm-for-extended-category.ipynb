# %% [markdown]
# ## Set up environment

# %%
from dotenv import load_dotenv

_ = load_dotenv(override=True)

# %%
from common.context import LLMTagPredictionContext

EXPERIMENT_ID = "2024-10-24-try-llm-for-extended-category"
RUN_ID = "on-events-dataset-v1--1-example-per-category"
EXAMPLE_COUNT = 1
RANDOM_SEED = 45

CONTEXT = LLMTagPredictionContext(
    description="Evaluate performance of the existing solution to set a baseline",
    experiment_id=EXPERIMENT_ID,
    run_id=RUN_ID,
    tags_in_scope=sorted(
        [
            "boulders",
            "harddrilling",
            "holecleaning",
            "lostcirculation",
            "other",
            "packoff",
            "shallowgas",
            "stuck",
            "tighthole",
            "waterflow",
            "wellborestability",
            "wellcontrol",
        ]
    ),
    with_notags=True,
    random_seed=RANDOM_SEED,
)

# %% [markdown]
# ## Fetch datasets

# %%
from common.datasets import load_input_dataset

dataset_name = "reviewed_distributed_events.csv"

dataset_df = load_input_dataset(
    dataset_name, columns_to_convert_to_sets=["tags", "Reviewed tags"]
)

CONTEXT.used_datasets = [dataset_name]

# %%
import pandas as pd


shuffled_dataset_df = dataset_df.sample(frac=1, random_state=CONTEXT.random_seed).reset_index(drop=True)


examples = shuffled_dataset_df[shuffled_dataset_df["description"].str.len() > 40]

examples_per_category = [
    examples[examples["extendedCategory"] == ext_category].head(EXAMPLE_COUNT)
    for ext_category in CONTEXT.tags_in_scope
]

# Concatenate the examples into a single DataFrame
examples = pd.concat(examples_per_category, ignore_index=True)
# Convert 'Reviewed tags' to a sorted list
examples["Reviewed tags"] = examples["Reviewed tags"].apply(sorted)

# Drop duplicate rows
examples_df = examples.drop_duplicates("id").sort_values(by="id")
examples_df
# Out:
#                                                    id       scope  \
# 9   a1f86f80-135e-458b-aafc-3af30d2476f2_main_11ea...  Subsurface
# 3   a1f86f80-135e-458b-aafc-3af30d2476f2_main_35a8...  Subsurface
# 0   a1f86f80-135e-458b-aafc-3af30d2476f2_main_3bf2...  Subsurface
# 7   a1f86f80-135e-458b-aafc-3af30d2476f2_main_6cf3...  Subsurface
# 2   a1f86f80-135e-458b-aafc-3af30d2476f2_main_7079...  Subsurface
# 11  a1f86f80-135e-458b-aafc-3af30d2476f2_main_7754...  Subsurface
# 1   a1f86f80-135e-458b-aafc-3af30d2476f2_main_8864...  Subsurface
# 6   a1f86f80-135e-458b-aafc-3af30d2476f2_main_8ad3...  Subsurface
# 10  a1f86f80-135e-458b-aafc-3af30d2476f2_main_c6aa...  Subsurface
# 4   a1f86f80-135e-458b-aafc-3af30d2476f2_main_d483...  Subsurface
# 8   a1f86f80-135e-458b-aafc-3af30d2476f2_main_e12b...  Subsurface
# 5   a1f86f80-135e-458b-aafc-3af30d2476f2_main_e5ee...  Subsurface
#
#                                                 title  \
# 9                           Shallow water flow (kick)
# 3                                             MudLoss
# 0                                            Boulders
# 7                Stuck pipe due to poor hole cleaning
# 2                                   Optimising of ROP
# 11                              12 bbl gain in Active
# 1   Reduced ROP // negative drill break in Lange, ...
# 6                   Kick - shallow water flow and gas
# 10                                           Packoffs
# 4                                             Kickoff
# 8                                         Tight spots
# 5   Pack-off and stalling tendancies throughtout w...
#
#                                           description   extendedCategory  \
# 9   After KO and sliding from 550m MD, significant...          waterflow
# 3   25% losses (FWR)         Category: Hydraulics,...    lostcirculation
# 0   Slow drilling and vibrations. Local Lessons Le...           boulders
# 7   High ROP through unconsolidated sands resulted...              stuck
# 2   Drilling 23"x17" section it was found that ROP...       holecleaning
# 11  12 bbl gain in Active at 3299m. Flowchecked – ...        wellcontrol
# 1   Drilled with an ROP as expected until half way...       harddrilling
# 6   Observed water flow with associated gas from 8...         shallowgas
# 10  Packoffs- due to poor hole cleaning when using...  wellborestability
# 4   Original hole, Mudline 129.5 m         Categor...              other
# 8   When running in hole with the 20" casing, the ...          tighthole
# 5   Decision make to POOH to surface to P&A well. ...            packoff
#
#                                        tags Are tags correct?  \
# 9               {wellcontrol, shallowwater}               YES
# 3                         {lostcirculation}               YES
# 0                                {boulders}                NO
# 7        {stuckpipe, highrop, holecleaning}               YES
# 2                   {highrop, holecleaning}               YES
# 11                            {wellcontrol}               YES
# 1                    {harddrilling, lowrop}               YES
# 6   {wellcontrol, shallowgas, shallowwater}               YES
# 10        {holecleaning, wellborestability}                NO
# 4                                        {}               YES
# 8                 {holecleaning, tighthole}               YES
# 5                                 {packoff}               YES
#
#                                         Reviewed tags  Comments
# 9                         [shallowwater, wellcontrol]       NaN
# 3                                   [lostcirculation]       NaN
# 0   [boulders, harddrilling, lowrop, wellborestabi...       NaN
# 7                  [highrop, holecleaning, stuckpipe]       NaN
# 2                             [highrop, holecleaning]       NaN
# 11                                      [wellcontrol]       NaN
# 1                              [harddrilling, lowrop]       NaN
# 6             [shallowgas, shallowwater, wellcontrol]       NaN
# 10         [holecleaning, packoff, wellborestability]       NaN
# 4                                                  []       NaN
# 8                           [holecleaning, tighthole]       NaN
# 5                                           [packoff]       NaN

# %%
# remove the examples from the dataset
test_dataset_df = dataset_df[~dataset_df["id"].isin(examples["id"])]
test_dataset_df
# Out:
#                                                     id       scope  \
# 0    a1f86f80-135e-458b-aafc-3af30d2476f2_main_50aa...  Subsurface
# 1    a1f86f80-135e-458b-aafc-3af30d2476f2_main_3806...  Subsurface
# 2    a1f86f80-135e-458b-aafc-3af30d2476f2_main_154d...  Subsurface
# 3    a1f86f80-135e-458b-aafc-3af30d2476f2_main_7fea...  Subsurface
# 4    a1f86f80-135e-458b-aafc-3af30d2476f2_main_aab3...  Subsurface
# ..                                                 ...         ...
# 333  a1f86f80-135e-458b-aafc-3af30d2476f2_main_9fdf...  Subsurface
# 335  a1f86f80-135e-458b-aafc-3af30d2476f2_main_daa4...  Subsurface
# 336  a1f86f80-135e-458b-aafc-3af30d2476f2_main_2f0c...  Subsurface
# 337  a1f86f80-135e-458b-aafc-3af30d2476f2_main_b543...  Subsurface
# 338  a1f86f80-135e-458b-aafc-3af30d2476f2_main_48c3...  Subsurface
#
#                                                  title  \
# 0                                     Lossesin Heimdal
# 1                                 Fault Related Losses
# 2                                            Stringers
# 3                                Losses in Balder Tuff
# 4                                               Losses
# ..                                                 ...
# 333  Positive drilling break when drilling into Kai...
# 335                                            Kickoff
# 336                                            Kickoff
# 337                                            Kickoff
# 338                                            Kickoff
#
#                                            description extendedCategory  \
# 0    Heimdal 3754m dynamic mud losses at 6m3/hrs wi...  lostcirculation
# 1    Fault was drilled. Mud  losses  of  14m3/hr  o...  lostcirculation
# 2    Set TD early due to not able to penetrate a st...     harddrilling
# 3    Observed indications off losses at 4353 m MD B...  lostcirculation
# 4    Drilled horizontally through Balder / UDC sand...  lostcirculation
# ..                                                 ...              ...
# 333  Possible positive drilling break at Top Kai. T...            other
# 335  Kicked off 2/8-F-7 T3         Category: Direct...            other
# 336  Kicked off 2/8-N-5 T4         Category: Direct...            other
# 337  Original hole, Mudline 110.3 m         Categor...            other
# 338  Original hole, Mudline 112.7 m         Categor...            other
#
#                                                   tags Are tags correct?  \
# 0                                    {lostcirculation}               YES
# 1                                    {lostcirculation}               YES
# 2    {harddrilling, wellborebreathing, lostcirculat...                NO
# 3                       {wellcontrol, lostcirculation}               YES
# 4                 {lostcirculation, wellborestability}               YES
# ..                                                 ...               ...
# 333                                                 {}               YES
# 335                                                 {}               YES
# 336                                                 {}               YES
# 337                                                 {}               YES
# 338                                                 {}               YES
#
#                                          Reviewed tags  Comments
# 0                                    {lostcirculation}       NaN
# 1                                    {lostcirculation}       NaN
# 2    {harddrilling, wellborebreathing, lostcirculat...       NaN
# 3                       {wellcontrol, lostcirculation}       NaN
# 4                 {lostcirculation, wellborestability}       NaN
# ..                                                 ...       ...
# 333                                                 {}       NaN
# 335                                                 {}       NaN
# 336                                                 {}       NaN
# 337                                                 {}       NaN
# 338                                                 {}       NaN
#
# [323 rows x 9 columns]

# %% [markdown]
# ## Apply the model

# %%
SYSTEM_PROMPT = f"""
You will be given a description of a drilling event, and your task is to determine the extended category of this event.
Available extended categories are: {', '.join(CONTEXT.tags_in_scope)}

Respond in 2 lines:
1. Think about the extended category that best describes the event. Refer to the examples.
2. Write a single word: the extended category that best applies to the event.
"""


def format_event(item):
    return f"Scope: {item['scope']}\nTitle: {item['title']}\n{item['description']}"

for idx, (_, row) in enumerate(examples.iterrows()):
    SYSTEM_PROMPT += f"\n## Example event {idx}\n{format_event(row)}\nExtended category: {row['extendedCategory']}\n"

CONTEXT.llm_system_prompt = SYSTEM_PROMPT

print(SYSTEM_PROMPT)
print(len(SYSTEM_PROMPT))
# Out:
# You will be given a description of a drilling event, and your task is to determine the extended category of this event.
# Available extended categories are: boulders, harddrilling, holecleaning, lostcirculation, other, packoff, shallowgas, stuck, tighthole, waterflow, wellborestability, wellcontrol
#
# Respond in 2 lines:
# 1. Think about the extended category that best describes the event. Refer to the examples.
# 2. Write a single word: the extended category that best applies to the event.
#
# ## Example event 0
# Scope: Subsurface
# Title: Boulders
# Slow drilling and vibrations. Local Lessons Learned: See FWR. Category: Wellbore stability. Sub-category: Wellbore stability
# Extended category: boulders
#
# ## Example event 1
# Scope: Subsurface
# Title: Reduced ROP // negative drill break in Lange, Spekk and Melke Fm
# Drilled with an ROP as expected until half way into the Lange formation, where the ROP started decreasing. above Top Spekk, the ROP dropped to 2m/hr and the next 300m
# Extended category: harddrilling
#
# ## Example event 2
# Scope: Subsurface
# Title: Optimising of ROP
# Drilling 23"x17" section it was found that ROP could be optimised at 40 to 60 mtrs before the clay sand zone and 35 to 40 mtrs/hr for good hole cleaning during the diffferent lithologies.         Category: Hydraulics, Subcategory: Good hole cleaning at high ROP
# Extended category: holecleaning
#
# ## Example event 3
# Scope: Subsurface
# Title: MudLoss
# 25% losses (FWR)         Category: Hydraulics, Subcategory: Loss circulation
# Extended category: lostcirculation
#
# ## Example event 4
# Scope: Subsurface
# Title: Kickoff
# Original hole, Mudline 129.5 m         Category: Directional drilling, Subcategory: Sidetrack
# Extended category: other
#
# ## Example event 5
# Scope: Subsurface
# Title: Pack-off and stalling tendancies throughtout whole stand.
# Decision make to POOH to surface to P&A well. Activity: Backream stand from 4432 to 4400m. Formation: FarsundSiltstone Mud: Omni-flow OBM1.25
# Extended category: packoff
#
# ## Example event 6
# Scope: Subsurface
# Title: Kick - shallow water flow and gas
# Observed water flow with associated gas from 800m. Killed well with mud and continued to drill with 1.20 sg. flowchecked with 1.20 sg mud. indications of gas bubbles. displaced pilot hole to 1.30 sg mud. well stable.
# Extended category: shallowgas
#
# ## Example event 7
# Scope: Subsurface
# Title: Stuck pipe due to poor hole cleaning
# High ROP through unconsolidated sands resulted in stuck pipe. Pipe was cut and fished. Well was respudded.         Category: Wellbore stability, Subcategory: Wellbore stability
# Extended category: stuck
#
# ## Example event 8
# Scope: Subsurface
# Title: Tight spots
# When running in hole with the 20" casing, the casing took weight and had to be washed down. Category: Hydraulics, SubCategory: Poor hole cleaning
# Extended category: tighthole
#
# ## Example event 9
# Scope: Subsurface
# Title: Shallow water flow (kick)
# After KO and sliding from 550m MD, significant flow was observed from the well. Stable after displacing to 1.30sg WBM
# Extended category: waterflow
#
# ## Example event 10
# Scope: Subsurface
# Title: Packoffs
# Packoffs- due to poor hole cleaning when using motor and sliding excessively         Category: Wellbore stability, Subcategory: Sloughing or packoffs
# Extended category: wellborestability
#
# ## Example event 11
# Scope: Subsurface
# Title: 12 bbl gain in Active
# 12 bbl gain in Active at 3299m. Flowchecked – 1 bbl gain in triptank. Shut in well and observed. Opened well, no flow. Category: Hydraulics, Subcategory: Other influx or kicks
# Extended category: wellcontrol
#
# 3548

# %%
TEMPERATURE = 0

CONTEXT.llm_temperature = TEMPERATURE

# %%
from concurrent.futures import ThreadPoolExecutor
import os
import string
from tqdm.auto import tqdm
from common.llm import ask_openai


# Define a function to call ask_openai and get the predicted tags
def get_predicted_category(text):
    try:
        response = ask_openai(
            azure_endpoint=os.environ["AZURE_OPENAI_ENDPOINT"],
            api_key=os.environ["AZURE_OPENAI_KEY"],
            api_version=os.environ["AZURE_OPENAI_API_VERSION"],
            deployment_name=os.environ["AZURE_OPENAI_DEPLOYMENT_ID"],
            system_prompt=SYSTEM_PROMPT,
            prompt=text,
        )
    except Exception as e:
        if "content management policy. Please modify your prompt" in str(e):
            print(e)
            return []  # running into the content filter
        raise

    correct_categories = set(CONTEXT.tags_in_scope)

    def normalize(t):
        # sometimes model makes mistakes
        while True:
            new_t = t.lower().strip().strip(string.punctuation).strip(string.digits)
            if new_t.startswith("extended category"):
                new_t = new_t[len("extended category"):]
            if new_t == t:
                break
            t = new_t
        
        t = t.lower().strip().strip(string.punctuation).strip(string.digits)
        if t not in correct_categories:
            print('Bad category:', t)
        return t

    response = response.strip()

    items = response.rsplit('\n', 1) if '\n' in response else response.rsplit(None, 1)
    try:
        justification, category = items
    except ValueError:
        justification = "(missing)"
        category = items[0]

    return normalize(category), justification


assessed_df = test_dataset_df.copy()


def parallel_apply(df, func, num_threads: int):
    with ThreadPoolExecutor(max_workers=num_threads) as executor:
        results = list(
            tqdm(
                executor.map(
                    func, df.apply(lambda row: format_event(row.to_dict()), axis=1)
                ),
                total=len(df),
            )
        )
    return results


assessed_df[["predictedExtendedCategory", "justification"]] = parallel_apply(
    assessed_df, get_predicted_category, num_threads=3
)
assessed_df
# Out:
#   0%|          | 0/323 [00:00<?, ?it/s]
# 100%|██████████| 323/323 [00:51<00:00,  6.25it/s]
#                                                     id       scope  \
# 0    a1f86f80-135e-458b-aafc-3af30d2476f2_main_50aa...  Subsurface
# 1    a1f86f80-135e-458b-aafc-3af30d2476f2_main_3806...  Subsurface
# 2    a1f86f80-135e-458b-aafc-3af30d2476f2_main_154d...  Subsurface
# 3    a1f86f80-135e-458b-aafc-3af30d2476f2_main_7fea...  Subsurface
# 4    a1f86f80-135e-458b-aafc-3af30d2476f2_main_aab3...  Subsurface
# ..                                                 ...         ...
# 333  a1f86f80-135e-458b-aafc-3af30d2476f2_main_9fdf...  Subsurface
# 335  a1f86f80-135e-458b-aafc-3af30d2476f2_main_daa4...  Subsurface
# 336  a1f86f80-135e-458b-aafc-3af30d2476f2_main_2f0c...  Subsurface
# 337  a1f86f80-135e-458b-aafc-3af30d2476f2_main_b543...  Subsurface
# 338  a1f86f80-135e-458b-aafc-3af30d2476f2_main_48c3...  Subsurface
#
#                                                  title  \
# 0                                     Lossesin Heimdal
# 1                                 Fault Related Losses
# 2                                            Stringers
# 3                                Losses in Balder Tuff
# 4                                               Losses
# ..                                                 ...
# 333  Positive drilling break when drilling into Kai...
# 335                                            Kickoff
# 336                                            Kickoff
# 337                                            Kickoff
# 338                                            Kickoff
#
#                                            description extendedCategory  \
# 0    Heimdal 3754m dynamic mud losses at 6m3/hrs wi...  lostcirculation
# 1    Fault was drilled. Mud  losses  of  14m3/hr  o...  lostcirculation
# 2    Set TD early due to not able to penetrate a st...     harddrilling
# 3    Observed indications off losses at 4353 m MD B...  lostcirculation
# 4    Drilled horizontally through Balder / UDC sand...  lostcirculation
# ..                                                 ...              ...
# 333  Possible positive drilling break at Top Kai. T...            other
# 335  Kicked off 2/8-F-7 T3         Category: Direct...            other
# 336  Kicked off 2/8-N-5 T4         Category: Direct...            other
# 337  Original hole, Mudline 110.3 m         Categor...            other
# 338  Original hole, Mudline 112.7 m         Categor...            other
#
#                                                   tags Are tags correct?  \
# 0                                    {lostcirculation}               YES
# 1                                    {lostcirculation}               YES
# 2    {harddrilling, wellborebreathing, lostcirculat...                NO
# 3                       {wellcontrol, lostcirculation}               YES
# 4                 {lostcirculation, wellborestability}               YES
# ..                                                 ...               ...
# 333                                                 {}               YES
# 335                                                 {}               YES
# 336                                                 {}               YES
# 337                                                 {}               YES
# 338                                                 {}               YES
#
#                                          Reviewed tags  Comments  \
# 0                                    {lostcirculation}       NaN
# 1                                    {lostcirculation}       NaN
# 2    {harddrilling, wellborebreathing, lostcirculat...       NaN
# 3                       {wellcontrol, lostcirculation}       NaN
# 4                 {lostcirculation, wellborestability}       NaN
# ..                                                 ...       ...
# 333                                                 {}       NaN
# 335                                                 {}       NaN
# 336                                                 {}       NaN
# 337                                                 {}       NaN
# 338                                                 {}       NaN
#
#     predictedExtendedCategory  \
# 0             lostcirculation
# 1             lostcirculation
# 2           wellborestability
# 3             lostcirculation
# 4             lostcirculation
# ..                        ...
# 333               wellcontrol
# 335                     other
# 336                     other
# 337                     other
# 338                     other
#
#                                          justification
# 0    1. The event describes significant mud losses ...
# 1    1. The event describes significant mud losses ...
# 2    1. The event describes difficulties in drillin...
# 3    1. The event describes a situation where there...
# 4    1. The event describes a situation where drill...
# ..                                                 ...
# 333  1. The event describes a situation where an in...
# 335  The event describes a kickoff in directional d...
# 336  The event describes a directional drilling ope...
# 337  1. The event describes a kickoff for a directi...
# 338  This event describes a kickoff for directional...
#
# [323 rows x 11 columns]

# %%
# nothing to do, DDR tagging using regex rules is already applied to the dataset in this experiment
from common.assessment import expand_ext_categories

assessed_df = assessed_df.filter(
    items=[
        "id",
        "scope",
        "title",
        "description",
        "extendedCategory",
        "predictedExtendedCategory",
        "justification",
        "Comments",
    ]
)
assessed_df = expand_ext_categories(
    assessed_df,
    categories_in_scope=CONTEXT.tags_in_scope,
    ground_truth_column="extendedCategory",
    predicted_column="predictedExtendedCategory",
)
assessed_df
# Out:
#                                                     id       scope  \
# 0    a1f86f80-135e-458b-aafc-3af30d2476f2_main_50aa...  Subsurface
# 1    a1f86f80-135e-458b-aafc-3af30d2476f2_main_3806...  Subsurface
# 2    a1f86f80-135e-458b-aafc-3af30d2476f2_main_154d...  Subsurface
# 3    a1f86f80-135e-458b-aafc-3af30d2476f2_main_7fea...  Subsurface
# 4    a1f86f80-135e-458b-aafc-3af30d2476f2_main_aab3...  Subsurface
# ..                                                 ...         ...
# 333  a1f86f80-135e-458b-aafc-3af30d2476f2_main_9fdf...  Subsurface
# 335  a1f86f80-135e-458b-aafc-3af30d2476f2_main_daa4...  Subsurface
# 336  a1f86f80-135e-458b-aafc-3af30d2476f2_main_2f0c...  Subsurface
# 337  a1f86f80-135e-458b-aafc-3af30d2476f2_main_b543...  Subsurface
# 338  a1f86f80-135e-458b-aafc-3af30d2476f2_main_48c3...  Subsurface
#
#                                                  title  \
# 0                                     Lossesin Heimdal
# 1                                 Fault Related Losses
# 2                                            Stringers
# 3                                Losses in Balder Tuff
# 4                                               Losses
# ..                                                 ...
# 333  Positive drilling break when drilling into Kai...
# 335                                            Kickoff
# 336                                            Kickoff
# 337                                            Kickoff
# 338                                            Kickoff
#
#                                            description extendedCategory  \
# 0    Heimdal 3754m dynamic mud losses at 6m3/hrs wi...  lostcirculation
# 1    Fault was drilled. Mud  losses  of  14m3/hr  o...  lostcirculation
# 2    Set TD early due to not able to penetrate a st...     harddrilling
# 3    Observed indications off losses at 4353 m MD B...  lostcirculation
# 4    Drilled horizontally through Balder / UDC sand...  lostcirculation
# ..                                                 ...              ...
# 333  Possible positive drilling break at Top Kai. T...            other
# 335  Kicked off 2/8-F-7 T3         Category: Direct...            other
# 336  Kicked off 2/8-N-5 T4         Category: Direct...            other
# 337  Original hole, Mudline 110.3 m         Categor...            other
# 338  Original hole, Mudline 112.7 m         Categor...            other
#
#     predictedExtendedCategory  \
# 0             lostcirculation
# 1             lostcirculation
# 2           wellborestability
# 3             lostcirculation
# 4             lostcirculation
# ..                        ...
# 333               wellcontrol
# 335                     other
# 336                     other
# 337                     other
# 338                     other
#
#                                          justification  Comments  \
# 0    1. The event describes significant mud losses ...       NaN
# 1    1. The event describes significant mud losses ...       NaN
# 2    1. The event describes difficulties in drillin...       NaN
# 3    1. The event describes a situation where there...       NaN
# 4    1. The event describes a situation where drill...       NaN
# ..                                                 ...       ...
# 333  1. The event describes a situation where an in...       NaN
# 335  The event describes a kickoff in directional d...       NaN
# 336  The event describes a directional drilling ope...       NaN
# 337  1. The event describes a kickoff for a directi...       NaN
# 338  This event describes a kickoff for directional...       NaN
#
#      expected__boulders  actual__boulders  ...  expected__stuck  \
# 0                 False             False  ...            False
# 1                 False             False  ...            False
# 2                 False             False  ...            False
# 3                 False             False  ...            False
# 4                 False             False  ...            False
# ..                  ...               ...  ...              ...
# 333               False             False  ...            False
# 335               False             False  ...            False
# 336               False             False  ...            False
# 337               False             False  ...            False
# 338               False             False  ...            False
#
#      actual__stuck  expected__tighthole  actual__tighthole  \
# 0            False                False              False
# 1            False                False              False
# 2            False                False              False
# 3            False                False              False
# 4            False                False              False
# ..             ...                  ...                ...
# 333          False                False              False
# 335          False                False              False
# 336          False                False              False
# 337          False                False              False
# 338          False                False              False
#
#      expected__waterflow  actual__waterflow  expected__wellborestability  \
# 0                  False              False                        False
# 1                  False              False                        False
# 2                  False              False                        False
# 3                  False              False                        False
# 4                  False              False                        False
# ..                   ...                ...                          ...
# 333                False              False                        False
# 335                False              False                        False
# 336                False              False                        False
# 337                False              False                        False
# 338                False              False                        False
#
#      actual__wellborestability  expected__wellcontrol  actual__wellcontrol
# 0                        False                  False                False
# 1                        False                  False                False
# 2                         True                  False                False
# 3                        False                  False                False
# 4                        False                  False                False
# ..                         ...                    ...                  ...
# 333                      False                  False                 True
# 335                      False                  False                False
# 336                      False                  False                False
# 337                      False                  False                False
# 338                      False                  False                False
#
# [323 rows x 32 columns]

# %%
# from common.datasets import save_assessed_dataset


# save_assessed_dataset(
#     assessed_df,
#     context=CONTEXT,
#     experiment_id=EXPERIMENT_ID,
#     run_id=RUN_ID,
# )

# %% [markdown]
# ## Evaluate predicted tags

# %%
from common.evaluation import TagMatchingEvaluator


evaluator = TagMatchingEvaluator(
    assessed_df=assessed_df,
    tags_in_scope=CONTEXT.tags_in_scope,
    with_notags=CONTEXT.with_notags,
)

# %%
evaluator.eval_per_tag()
# Out:
#                   tag  precision    recall        f1  true_positives  \
# 0            boulders   0.360000  0.900000  0.514286               9
# 1        harddrilling   0.846154  0.468085  0.602740              22
# 2        holecleaning   0.857143  0.666667  0.750000              12
# 3     lostcirculation   0.864865  1.000000  0.927536              32
# 4               other   0.825397  0.764706  0.793893              52
# 5             packoff   0.190476  1.000000  0.320000               4
# 6          shallowgas   0.625000  0.833333  0.714286              10
# 7               stuck   0.692308  0.857143  0.765957              18
# 8           tighthole   0.904762  0.760000  0.826087              19
# 9           waterflow   1.000000  0.285714  0.444444               2
# 10  wellborestability   0.536585  0.349206  0.423077              22
# 11        wellcontrol   0.387097  0.750000  0.510638              12
#
#     positives_in_ground_truth  negatives_in_ground_truth
# 0                          10                        313
# 1                          47                        276
# 2                          18                        305
# 3                          32                        291
# 4                          68                        255
# 5                           4                        319
# 6                          12                        311
# 7                          21                        302
# 8                          25                        298
# 9                           7                        316
# 10                         63                        260
# 11                         16                        307

# %%
evaluator.eval_individual_ddrs()
# Out:
#                                                     id       scope  \
# 0    a1f86f80-135e-458b-aafc-3af30d2476f2_main_50aa...  Subsurface
# 1    a1f86f80-135e-458b-aafc-3af30d2476f2_main_3806...  Subsurface
# 2    a1f86f80-135e-458b-aafc-3af30d2476f2_main_154d...  Subsurface
# 3    a1f86f80-135e-458b-aafc-3af30d2476f2_main_7fea...  Subsurface
# 4    a1f86f80-135e-458b-aafc-3af30d2476f2_main_aab3...  Subsurface
# ..                                                 ...         ...
# 333  a1f86f80-135e-458b-aafc-3af30d2476f2_main_9fdf...  Subsurface
# 335  a1f86f80-135e-458b-aafc-3af30d2476f2_main_daa4...  Subsurface
# 336  a1f86f80-135e-458b-aafc-3af30d2476f2_main_2f0c...  Subsurface
# 337  a1f86f80-135e-458b-aafc-3af30d2476f2_main_b543...  Subsurface
# 338  a1f86f80-135e-458b-aafc-3af30d2476f2_main_48c3...  Subsurface
#
#                                                  title  \
# 0                                     Lossesin Heimdal
# 1                                 Fault Related Losses
# 2                                            Stringers
# 3                                Losses in Balder Tuff
# 4                                               Losses
# ..                                                 ...
# 333  Positive drilling break when drilling into Kai...
# 335                                            Kickoff
# 336                                            Kickoff
# 337                                            Kickoff
# 338                                            Kickoff
#
#                                            description extendedCategory  \
# 0    Heimdal 3754m dynamic mud losses at 6m3/hrs wi...  lostcirculation
# 1    Fault was drilled. Mud  losses  of  14m3/hr  o...  lostcirculation
# 2    Set TD early due to not able to penetrate a st...     harddrilling
# 3    Observed indications off losses at 4353 m MD B...  lostcirculation
# 4    Drilled horizontally through Balder / UDC sand...  lostcirculation
# ..                                                 ...              ...
# 333  Possible positive drilling break at Top Kai. T...            other
# 335  Kicked off 2/8-F-7 T3         Category: Direct...            other
# 336  Kicked off 2/8-N-5 T4         Category: Direct...            other
# 337  Original hole, Mudline 110.3 m         Categor...            other
# 338  Original hole, Mudline 112.7 m         Categor...            other
#
#     predictedExtendedCategory  \
# 0             lostcirculation
# 1             lostcirculation
# 2           wellborestability
# 3             lostcirculation
# 4             lostcirculation
# ..                        ...
# 333               wellcontrol
# 335                     other
# 336                     other
# 337                     other
# 338                     other
#
#                                          justification  Comments  \
# 0    1. The event describes significant mud losses ...       NaN
# 1    1. The event describes significant mud losses ...       NaN
# 2    1. The event describes difficulties in drillin...       NaN
# 3    1. The event describes a situation where there...       NaN
# 4    1. The event describes a situation where drill...       NaN
# ..                                                 ...       ...
# 333  1. The event describes a situation where an in...       NaN
# 335  The event describes a kickoff in directional d...       NaN
# 336  The event describes a directional drilling ope...       NaN
# 337  1. The event describes a kickoff for a directi...       NaN
# 338  This event describes a kickoff for directional...       NaN
#
#      expected__boulders  actual__boulders  ...  expected__wellborestability  \
# 0                 False             False  ...                        False
# 1                 False             False  ...                        False
# 2                 False             False  ...                        False
# 3                 False             False  ...                        False
# 4                 False             False  ...                        False
# ..                  ...               ...  ...                          ...
# 333               False             False  ...                        False
# 335               False             False  ...                        False
# 336               False             False  ...                        False
# 337               False             False  ...                        False
# 338               False             False  ...                        False
#
#      actual__wellborestability  expected__wellcontrol  actual__wellcontrol  \
# 0                        False                  False                False
# 1                        False                  False                False
# 2                         True                  False                False
# 3                        False                  False                False
# 4                        False                  False                False
# ..                         ...                    ...                  ...
# 333                      False                  False                 True
# 335                      False                  False                False
# 336                      False                  False                False
# 337                      False                  False                False
# 338                      False                  False                False
#
#      expected__notags  actual__notags  precision  recall   f1  true_positives
# 0               False           False        1.0     1.0  1.0               1
# 1               False           False        1.0     1.0  1.0               1
# 2               False           False        0.0     0.0  0.0               0
# 3               False           False        1.0     1.0  1.0               1
# 4               False           False        1.0     1.0  1.0               1
# ..                ...             ...        ...     ...  ...             ...
# 333             False           False        0.0     0.0  0.0               0
# 335             False           False        1.0     1.0  1.0               1
# 336             False           False        1.0     1.0  1.0               1
# 337             False           False        1.0     1.0  1.0               1
# 338             False           False        1.0     1.0  1.0               1
#
# [323 rows x 38 columns]

# %%
evaluator.average_metrics()
# Out:
#               Type  precision    recall        f1
# 0  Average per DDR   0.662539  0.662539  0.662539
# 1  Average per Tag   0.674149  0.719571  0.632745

# %% [markdown]
# ## Save evaluation report

# %%
from common.datasets import save_evaluation_report

save_evaluation_report(
    experiment_id=EXPERIMENT_ID,
    run_id=RUN_ID,
    dataset_df=dataset_df,
    assessed_df=assessed_df,
    evaluator=evaluator,
    context=CONTEXT,
)
